# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path='https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx'

# %% [markdown]
# TASK 1

# %%
data=pd.read_excel(path)

# %%
data.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
d1=data.loc[data['InvoiceNo'] == 536544]
d1 = d1.iloc[:, 0:4]
d1.head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
# 1447    536544     21790               VINTAGE SNAP CARDS         9

# %%
d2=data[['StockCode','UnitPrice']]

# %%
d2['UnitPrice'].describe()
# Out:
# count    541909.000000
# mean          4.611114
# std          96.759853
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
print('Median',d2['UnitPrice'].median(),'Variance',d2['UnitPrice'].var())
# Out:
# Median 2.08 Variance 9362.469164424467

# %%
d3=data.iloc[100:,:].sort_values('InvoiceDate')

# %%
d3[d3['Description'].str.startswith('D',na=False)]
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 140       536381     21523  ...    15311.0  United Kingdom
# 141      C536379         D  ...    14527.0  United Kingdom
# 185       536388     21523  ...    16250.0  United Kingdom
# 228       536390     22654  ...    17511.0  United Kingdom
# 219       536390     20668  ...    17511.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541653    581538     23033  ...    14446.0  United Kingdom
# 541651    581538     23034  ...    14446.0  United Kingdom
# 541727    581570     23077  ...    12662.0         Germany
# 541733    581571     48187  ...    15311.0  United Kingdom
# 541893    581586     20685  ...    13113.0  United Kingdom
#
# [19404 rows x 8 columns]

# %% [markdown]
# TASK 2

# %%
data=pd.DataFrame({'DOB':['19-10-1999','21-04-1997','23-08-1998','08-08-2008','10-12-1994'],'Student Name':['Shyam','Rohan','Mohan','Geeta','Seeta'],'Marks(maths)':[94,93,92,98,96]})

# %%
list_of_dict=[{'DOB':'1999-12-12','Student Name':'Meeta','Marks(maths)':'90'}]

# %%
data=pd.DataFrame(list_of_dict)

# %%
list_of_list=[['19-10-1999','Shyam','94']]

# %%
data=data.append(pd.DataFrame(list_of_list,columns=['DOB','Student Name','Marks(maths)']))

# %%
dict_of_arr={'DOB':['21-04-1997','23-08-1998'],'Student Name':['Rohan','Mohan'],'Marks(maths)':[93,92]}

# %%
data=data.append(pd.DataFrame(dict_of_arr))

# %%
data.head()
# Out:
#           DOB Student Name Marks(maths)
# 0  1999-12-12        Meeta           90
# 0  19-10-1999        Shyam           94
# 0  21-04-1997        Rohan           93
# 1  23-08-1998        Mohan           92

# %%
data['DOB']=pd.to_datetime(data['DOB'])

# %%
data.head()
# Out:
#          DOB Student Name Marks(maths)
# 0 1999-12-12        Meeta           90
# 0 1999-10-19        Shyam           94
# 0 1997-04-21        Rohan           93
# 1 1998-08-23        Mohan           92

# %%
new_df=pd.DataFrame(columns=['DOB','StudentName','Marks(English)'])

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [DOB, StudentName, Marks(English)]
# Index: []

# %%
new_df=new_df.append(pd.DataFrame([['19-10-1999','SHYAM','99']],columns=['DOB','StudentName','Marks(English)']))

# %%
new_df=new_df.append(pd.DataFrame([['22-01-1992','MANAV','99']],columns=['DOB','StudentName','Marks(English)']))

# %%
new_df=new_df.append(pd.DataFrame([['21-10-2000','SRIRAM','99']],columns=['DOB','StudentName','Marks(English)']))

# %%
new_df=new_df.append(pd.DataFrame([['10-06-1998','RAM','39']],columns=['DOB','StudentName','Marks(English)']))

# %%
new_df=new_df.append(pd.DataFrame([['19-03-1997','HELLO','99']],columns=['DOB','StudentName','Marks(English)']))

# %%
new_df.head()
# Out:
#           DOB StudentName Marks(English)
# 0  19-10-1999       SHYAM             99
# 0  22-01-1992       MANAV             99
# 0  21-10-2000      SRIRAM             99
# 0  10-06-1998         RAM             39
# 0  19-03-1997       HELLO             99

# %% [markdown]
# TASK 3

# %%
df1 = pd.DataFrame(np.random.randint(0,100,size=(100,1)), columns=['A'])

# %%
df2 = pd.DataFrame(np.random.randint(0,100,size=(100,1)), columns=['B'])

# %%
finaldf=df1
finaldf=finaldf.rename(columns={'A':'number1'})

# %%
finaldf['number2']=df2['B']
finaldf['sum']=finaldf['number1'].add(finaldf['number2'])
finaldf['difference']=finaldf['number1'].sub(finaldf['number2'])
finaldf['multiply']=finaldf['number1'].multiply(finaldf['number2'])
finaldf['div']=finaldf['number1'].div(finaldf['number2'])

# %%
finaldf
# Out:
#     number1  number2  sum  difference  multiply        div
# 0        94        7  101          87       658  13.428571
# 1        18       10   28           8       180   1.800000
# 2        75       55  130          20      4125   1.363636
# 3        83       52  135          31      4316   1.596154
# 4        54       95  149         -41      5130   0.568421
# ..      ...      ...  ...         ...       ...        ...
# 95       19       73   92         -54      1387   0.260274
# 96       90       21  111          69      1890   4.285714
# 97       96       41  137          55      3936   2.341463
# 98       99       60  159          39      5940   1.650000
# 99       64       47  111          17      3008   1.361702
#
# [100 rows x 6 columns]
