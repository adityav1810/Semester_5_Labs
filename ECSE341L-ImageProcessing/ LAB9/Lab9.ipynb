# %% [markdown]
# <a href="https://colab.research.google.com/github/adityav1810/Semester_5_Labs/blob/master/ECSE341L-ImageProcessing/%20LAB9/Lab9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://picsum.photos/200/300.jpg
# Out:
# --2020-11-02 13:29:50--  https://picsum.photos/200/300.jpg
# Resolving picsum.photos (picsum.photos)... 172.67.74.163, 104.26.4.30, 104.26.5.30, ...
# Connecting to picsum.photos (picsum.photos)|172.67.74.163|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://i.picsum.photos/id/334/200/300.jpg?hmac=mY7moKpyBD1N0PF_abyW5_eUHxm9jV4JxZWPnxY7x3Q [following]
# --2020-11-02 13:29:50--  https://i.picsum.photos/id/334/200/300.jpg?hmac=mY7moKpyBD1N0PF_abyW5_eUHxm9jV4JxZWPnxY7x3Q
# Resolving i.picsum.photos (i.picsum.photos)... 172.67.74.163, 104.26.5.30, 104.26.4.30, ...
# Connecting to i.picsum.photos (i.picsum.photos)|172.67.74.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4492 (4.4K) [image/jpeg]
# Saving to: ‘300.jpg’
#
# 300.jpg             100%[===================>]   4.39K  --.-KB/s    in 0s
#
# 2020-11-02 13:29:50 (53.5 MB/s) - ‘300.jpg’ saved [4492/4492]

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from scipy import misc
from PIL import Image
image_path='/content/300.jpg'

# %%
im=cv2.imread(image_path)

# %%
cv2_imshow(im)
print(im.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x7FF24428F710>
# (300, 200, 3)

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(5,5))
gradient = cv2.morphologyEx(im, cv2.MORPH_GRADIENT, kernel)

# %%
cv2_imshow(gradient)
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x7FF24428FBE0>

# %%
q2_img = cv2.imread("/content/lab9-1.png", cv2.IMREAD_GRAYSCALE);
th, im_th = cv2.threshold(q2_img, 220, 255, cv2.THRESH_BINARY_INV);
im_floodfill = im_th.copy()
h, w = im_th.shape[:2]
mask = np.zeros((h+2, w+2), np.uint8)
cv2.floodFill(im_floodfill, mask, (0,0), 255);
im_floodfill_inv = cv2.bitwise_not(im_floodfill)
im_out = im_th | im_floodfill_inv
cv2_imshow( q2_img)
cv2_imshow( im_out)
# Out:
# <PIL.Image.Image image mode=L size=448x439 at 0x7FF233B134A8>
# <PIL.Image.Image image mode=L size=448x439 at 0x7FF233B13748>

# %%
img=cv2.imread('/content/lab9.png')
kernel = np.ones((1,5), np.uint8)   
img_erosion = cv2.erode(img, kernel, iterations=1) 
print('Original Image')
cv2_imshow(img) 
print('Binary Erosion with 1 x 5 kernel')
cv2_imshow( img_erosion) 
kernel = np.ones((1,15), np.uint8)   
img_erosion = cv2.erode(img, kernel, iterations=1) 
print('Binary Erosion with 1 x 15 kernel')
cv2_imshow( img_erosion)
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=391x187 at 0x7FF22AF6DE10>
# Binary Erosion with 1 x 5 kernel
# <PIL.Image.Image image mode=RGB size=391x187 at 0x7FF22AF6D748>
# Binary Erosion with 1 x 15 kernel
# <PIL.Image.Image image mode=RGB size=391x187 at 0x7FF22AF6DE10>
