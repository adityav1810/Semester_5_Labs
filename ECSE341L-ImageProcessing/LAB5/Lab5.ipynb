# %% [markdown]
# <a href="https://colab.research.google.com/github/adityav1810/Semester_5_Labs/blob/master/ECSE341L-ImageProcessing/LAB5/Lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path='https://picsum.photos/400'

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

import matplotlib.pyplot as plt
import math
from skimage import data
from skimage import transform
from skimage import img_as_float

# %%
img_path='/content/drive/My Drive/BTECH SEM 5/Image&VideoProcessing/LAB4/8bitimg.jpg'

# %%
img=cv2.imread(img_path)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F00F2773C50>

# %%
matrix = tform.params.copy()
matrix[0, 2]=30
matrix[1, 2]=-10 
tform2 = transform.SimilarityTransform(matrix)
img = img_as_float(img)
tf_img = transform.warp(img, tform2.inverse)
fig, ax = plt.subplots()
ax.imshow(tf_img)
_ = ax.set_title('Geometric transformation Bx=30, By=-10')

# %%
matrix = tform.params.copy()
matrix[0, 2]=30
matrix[1, 2]=10 
tform2 = transform.SimilarityTransform(matrix)
img = img_as_float(img)
tf_img = transform.warp(img, tform2.inverse)
fig, ax = plt.subplots()
ax.imshow(tf_img)
_ = ax.set_title('Geometric transformation Bx=30, By=10')
